# %%
# ===========================================
# CAMPUS ENTITY FUZZY SEARCH + DASHBOARD + TIMELINE
# ===========================================

# !pip install rapidfuzz matplotlib

import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
from rapidfuzz import process, fuzz

# 1️⃣ CONNECT TO DATABASE
# -------------------------------------------
db_path = "campus_er.db"
conn = sqlite3.connect(db_path)

# 2️⃣ FUZZY SEARCH FUNCTION
# -------------------------------------------
def fuzzy_search(query, top_n=5, min_score=60):
    df_entities = pd.read_sql_query("SELECT * FROM entities;", conn)
    df_entities['combined'] = df_entities['name'].fillna('') + " | " + df_entities['email'].fillna('')
    results = process.extract(query, df_entities['combined'], scorer=fuzz.token_set_ratio, limit=top_n)

    matches = []
    for match_text, score, idx in results:
        if score >= min_score:
            row = df_entities.iloc[idx]
            matches.append({
                "entity_id": row['entity_id'],
                "name": row['name'],
                "email": row['email'],
                "role": row['role'],
                "similarity": score
            })
    return pd.DataFrame(matches)

# 3️⃣ FETCH RELATED DATA
# -------------------------------------------
def fetch_related_data(entity_id):
    print(f"\n📘 ENTITY PROFILE for {entity_id}")

    # ENTITY INFO
    entity = pd.read_sql_query(f"SELECT * FROM entities WHERE entity_id='{entity_id}';", conn)
    display(entity)

    # EVENTS
    events = pd.read_sql_query(f"SELECT * FROM events WHERE entity_id='{entity_id}';", conn)

    # NOTES
    notes = pd.read_sql_query(f"SELECT * FROM notes WHERE entity_id='{entity_id}';", conn)

    # FACE EMBEDDINGS
    faces = pd.read_sql_query(f"SELECT * FROM face_embeddings WHERE entity_id='{entity_id}';", conn)

    # TRANSITIONS (GLOBAL)
    transitions = pd.read_sql_query("SELECT * FROM transitions ORDER BY count DESC LIMIT 10;", conn)

    # --- Display Summary Dashboard ---
    print("\n📊 DASHBOARD SUMMARY")
    print(f"Events logged: {len(events)}")
    print(f"Notes available: {len(notes)}")
    print(f"Face embeddings: {len(faces)}")

    if not events.empty:
        print(f"First seen: {events['timestamp'].min()}")
        print(f"Last seen: {events['timestamp'].max()}")
    else:
        print("No movement records available.")

    # --- Timeline Visualization ---
    if not events.empty:
        print("\n🕓 TIMELINE OF MOVEMENTS")
        events_sorted = events.sort_values("timestamp")
        plt.figure(figsize=(10,4))
        plt.plot(events_sorted['timestamp'], range(len(events_sorted)), marker='o')
        plt.title(f"Movement Timeline for {entity.iloc[0]['name']}")
        plt.xlabel("Timestamp")
        plt.ylabel("Event Sequence")
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
    else:
        print("No timeline data to plot.")

    # --- Detailed Views ---
    if not events.empty:
        print("\n📍 EVENTS:")
        display(events[['location', 'timestamp', 'source']])
    if not notes.empty:
        print("\n🗒️ NOTES:")
        display(notes[['timestamp', 'category', 'text']])
    if not faces.empty:
        print("\n📸 FACE EMBEDDINGS:")
        display(faces[['face_id', 'camera_id', 'timestamp']])

    print("\n🚶 GLOBAL MOVEMENT PATTERNS (Top 10):")
    display(transitions[['from_loc', 'to_loc', 'count', 'prob']])

# 4️⃣ MAIN WORKFLOW
# -------------------------------------------
query = input("🔍 Enter name or email to search: ").strip()
matches = fuzzy_search(query)

if matches.empty:
    print("❌ No matches found.")
else:
    print(f"\nTop matches for '{query}':")
    display(matches)

    # Automatically pick best match
    top_entity = matches.iloc[0]['entity_id']
    fetch_related_data(top_entity)
# Out:
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# 🔍 Enter name or email to search: Neha Mehta
#
# Top matches for 'Neha Mehta':
#   entity_id        name               email     role  similarity
# 0   E100000  Neha Mehta    user0@campus.edu  student       100.0
# 1   E100049  Neha Mehta   user49@campus.edu  student       100.0
# 2   E100100  Neha Mehta  user100@campus.edu  student       100.0
# 3   E100136  Neha Mehta  user136@campus.edu  student       100.0
# 4   E100225  Neha Mehta  user225@campus.edu  student       100.0
# 📘 ENTITY PROFILE for E100000
#    id entity_id student_id staff_id card_id     device_hash  face_id  \
# 0   1   E100000     S39256     None   C3286  DH6d0bd80c8f8e  F100000
#
#          name     role             email extra_metadata
# 0  Neha Mehta  student  user0@campus.edu           None
# 📊 DASHBOARD SUMMARY
# Events logged: 6
# Notes available: 0
# Face embeddings: 0
# First seen: 2025-08-29 07:41:18.000000
# Last seen: 2025-09-19 00:36:50.000000
#
# 🕓 TIMELINE OF MOVEMENTS
# 📍 EVENTS:
#       location                   timestamp source
# 0  HOSTEL_GATE  2025-08-29 07:41:18.000000  swipe
# 1      LIB_ENT  2025-09-02 13:58:39.000000  swipe
# 2   AUDITORIUM  2025-09-05 06:46:02.000000  swipe
# 3   AUDITORIUM  2025-09-12 19:18:02.000000  swipe
# 4      LAB_101  2025-09-19 00:36:50.000000  swipe
# 5      LAB_101  2025-09-04 02:31:00.000000   cctv
# 🚶 GLOBAL MOVEMENT PATTERNS (Top 10):
#       from_loc       to_loc  count      prob
# 0      LAB_101      LAB_101    493  0.193713
# 1      LAB_101   AUDITORIUM    358  0.140668
# 2      LIB_ENT      LAB_101    340  0.184282
# 3      LAB_101  ADMIN_LOBBY    340  0.133595
# 4      LAB_101      LIB_ENT    335  0.131631
# 5   AUDITORIUM      LAB_101    333  0.176845
# 6  ADMIN_LOBBY      LAB_101    332  0.178783
# 7      LAB_101  HOSTEL_GATE    331  0.130059
# 8      LAB_101       CAF_01    331  0.130059
# 9  HOSTEL_GATE      LAB_101    330  0.182825
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['prob'].plot(kind='hist', bins=20, title='prob')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('from_loc').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('to_loc').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='count', y='prob', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['count'].plot(kind='line', figsize=(8, 4), title='count')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['prob'].plot(kind='line', figsize=(8, 4), title='prob')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['to_loc'].value_counts()
#     for x_label, grp in _df_7.groupby('from_loc')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('from_loc')
# _ = plt.ylabel('to_loc')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['from_loc'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='count', y='from_loc', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['to_loc'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='count', y='to_loc', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['from_loc'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='prob', y='from_loc', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['to_loc'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='prob', y='to_loc', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
